# %% [markdown]
# # 0.Import

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import json
import re
import time
import logging
import pandas as pd
import json
import requests
import html
import numpy as np
import warnings
warnings.filterwarnings("ignore")

from pathlib import Path
from tqdm import trange, tqdm

# %% [markdown]
# # 1.AI허브 데이터 증강

# %%
# 영어를 번역하기 위한 Google Cloud Translation API 키
translation_api_key = ""

# %%
def translate_text(text, source_lang, target_only):

    url = f"https://translation.googleapis.com/language/translate/v2?key={translation_api_key}"
    data = {
        "q": text,
        "source": source_lang,
        "target": target_only
    }
    response = requests.post(url, data=data)
    translated_text = response.json()["data"]["translations"][0]["translatedText"]
    translated_text = html.unescape(translated_text)

    return translated_text

# %%
AI_hub_QA = pd.read_csv('/content/drive/MyDrive/절미네 가족들/1.jiwon/1.data/1.first_cleansing/AI_hub_QA_cleansing_before.csv')
AI_hub_QA_use = AI_hub_QA[['question', 'answer_text']]

# %%
# AI_hub_QA_use.to_csv('/content/drive/MyDrive/temp/AI_hub_QA.csv',index=False)

# %%
AI_hub_QA_use
# Out:
#                                                 question  \
# 0                           경기 변동성이 커지는 것에 대응하기 위해 어떻게 해
# 1                             어떤 방법으로 경기 변동성이 커지는 것을 대처해
# 2                          보험회사가 커지는 불확실성에 대해 어떻게 준비해야 돼
# 3                       불확실성이 커지는 보험회사는 어떤 방법으로 대비를 해야 돼
# 4                         금감원은 어떤 방법으로 온라인 업무설명회를 열기로 했어
# ...                                                  ...
# 18755  보증 중심의 금융관행에서 탈피하여 어떤 조치를 취해서 기술을 기반으로 한 사업화자금...
# 18756          투자자가 금융사기 때문에 손해를 입을 가능성을 감소시키려면 어떻게 해야 돼
# 18757           어떤 방법으로 투자자가 금융사기로 인한 손실을 볼 가능성을 줄일 수 있어
# 18758                   여러 가지 무형자산들을 어떻게 원활하게 상업화시킬 수 있어
# 18759                 어떤 방식으로 다양한 무형자산들을 순조롭게 상업화시킬 수 있어
#
#                                          answer_text
# 0                           연체율 등 대출 건전성 지표를 지속 모니터링
# 1                           연체율 등 대출 건전성 지표를 지속 모니터링
# 2               장기 수익성 및 자산운용 리스크 관리를 강화하고 재무건전성을 확보
# 3               장기 수익성 및 자산운용 리스크 관리를 강화하고 재무건전성을 확보
# ...

# %%
from tqdm.auto import tqdm

#처음 실행한 게 아니라면, 기존에 만들어둔 파일을 다시 불러온다
try :
    check_list = pd.read_csv('/content/drive/MyDrive/temp/QA_list.csv')
    qa_df_fn = pd.read_csv('/content/drive/MyDrive/temp/translated_QA.csv')

#처음 실행한 게 맞다면
except:
    qa_df_fn = pd.DataFrame(columns=['question','answer_text'])
    qa_df = pd.read_csv('/content/drive/MyDrive/temp/AI_hub_QA.csv')
    check_list = qa_df.copy()
    check_list = check_list[['question','answer_text']]
    check_list = check_list.rename(columns={'answer_text':'CHECK'})

    check_list['CHECK'] = np.nan

retrieve_list = check_list[check_list['CHECK'].isnull()].index

for idx in tqdm(retrieve_list):
  question_en = translate_text(str(qa_df.loc[idx,'question']), 'ko', 'en')
  answer_en = translate_text(str(qa_df.loc[idx,'answer_text']), 'ko', 'en')
  question_re = translate_text(question_en,'en','ko')
  answer_re = translate_text(answer_en, 'en','ko')

  qa_df_fn.loc[idx,'question'] = question_re
  qa_df_fn.loc[idx,'answer_text'] = answer_re

  check_list.loc[idx, 'CHECK'] = True

  check_list.to_csv('/content/drive/MyDrive/temp/QA_list.csv',index=False)
  qa_df_fn.to_csv('/content/drive/MyDrive/temp/translated_QA.csv',index=False)
# Out:
#   0%|          | 0/8417 [00:00<?, ?it/s]

# %% [markdown]
# # 2.FSS 데이터 증강

# %%
# 영어를 번역하기 위한 Google Cloud Translation API 키
translation_api_key = "AIzaSyC5M5ArbmrD1eIPKQxNl3dJo8xC_qbDvzY"

# %%
def translate_text(text, source_lang, target_only):

    url = f"https://translation.googleapis.com/language/translate/v2?key={translation_api_key}"
    data = {
        "q": text,
        "source": source_lang,
        "target": target_only
    }
    response = requests.post(url, data=data)
    translated_text = response.json()["data"]["translations"][0]["translatedText"]
    translated_text = html.unescape(translated_text)

    return translated_text

# %%
FSS_QA = pd.read_csv('/content/drive/MyDrive/절미네 가족들/1.jiwon/1.data/4.QA_data/QA_set_final_ver4.csv')
FSS_QA
# Out:
#                                             instruction  \
# 0                           경제활동의 주체들은 시장에서 어떤 역할을 하나요?
# 1           생산물시장과 요소시장은 각각 어떤 종류의 재화와 서비스를 거래하는 시장인가요?
# 2                          정부는 경제활동에서 어떤 모습으로 참여하고 있나요?
# 3                             정부는 어떤 목적으로 공공서비스를 제공하나요?
# 4                                 정부가 발행한 채권은 누가 구입하나요?
# ...                                                 ...
# 3454                    주민번호 도용을 확인할 수 있는 무료 방법은 무엇인가?
# 3455             금융소비자 보호에서 가장 큰 이슈로 부각되고 있는 것은 무엇인가요?
# 3456                   어떤 현실을 이용한 대학생 대상 사기가 증가하고 있나요?
# 3457  피해예방을 위해 어떤 경우에도 금전의 이체를 요구하거나, 금융거래정보를 수집하지 말...
# 3458  전화나 문자 메시지를 통한 대출 광고에 응하면 어떤 사기업체의 대출 광고에 노출될 ...
#
#                                                   input  \
# 0     경제활동은 우리 생활에 필요한 재화와 서비스를 생산·분배·소비하는 활동을 말한다 가...
# 1     경제활동은 우리 생활에 필요한 재화와 서비스를 생산·분배·소비하는 활동을 말한다 가...
# 2     경제활동은 우리 생활에 필요한 재화와 서비스를 생산·분배·소비하는 활동을 말한다 가...
# 3      과정에서 돈을 지불하거나 수취하게 된다 정부도 시장 경제의 순환과정에서 다양한 모...
# ...

# %%
from tqdm.auto import tqdm

#처음 실행한 게 아니라면, 기존에 만들어둔 파일을 다시 불러온다
try :
    check_list = pd.read_csv('/content/drive/MyDrive/temp2/QA_list.csv')
    qa_df_fn = pd.read_csv('/content/drive/MyDrive/temp2/translated_QA_FSS.csv')

#처음 실행한 게 맞다면
except:
    qa_df_fn = pd.DataFrame(columns=['instruction','output'])
    qa_df = pd.read_csv('/content/drive/MyDrive/절미네 가족들/1.jiwon/1.data/4.QA_data/QA_set_final_ver4.csv')
    check_list = qa_df.copy()
    check_list = check_list[['instruction','output']]
    check_list = check_list.rename(columns={'output':'CHECK'})

    check_list['CHECK'] = np.nan

retrieve_list = check_list[check_list['CHECK'].isnull()].index

for idx in tqdm(retrieve_list):
  question_en = translate_text(str(qa_df.loc[idx,'instruction']), 'ko', 'en')
  answer_en = translate_text(str(qa_df.loc[idx,'output']), 'ko', 'en')
  question_re = translate_text(question_en,'en','ko')
  answer_re = translate_text(answer_en, 'en','ko')

  qa_df_fn.loc[idx,'instruction'] = question_re
  qa_df_fn.loc[idx,'output'] = answer_re

  check_list.loc[idx, 'CHECK'] = True

  check_list.to_csv('/content/drive/MyDrive/temp2/QA_list.csv',index=False)
  qa_df_fn.to_csv('/content/drive/MyDrive/temp2/translated_QA_FSS.csv',index=False)
# Out:
#   0%|          | 0/3459 [00:00<?, ?it/s]
